# %%
import pandas as pd

# %%
df_filter = pd.read_csv('../data/raw/job_titles_to_run_june2024.csv')
columns = ['job_title','alternative_job_title','description_keywords']
df_filter.columns = columns
df_filter.head()
# Out:
#                job_title   alternative_job_title  \
# 0  architectural manager          design manager
# 1  architectural manager    construction manager
# 2  architectural manager  infrastructure manager
# 3    armoring technician          armor operator
# 4    armoring technician          cable operator
#
#                                 description_keywords
# 0  "wind energy" OR "offshore wind" OR "wind powe...
# 1  "wind energy" OR "offshore wind" OR "wind powe...
# 2  "wind energy" OR "offshore wind" OR "wind powe...
# 3  "wind energy" OR "offshore wind" OR "wind powe...
# 4  "wind energy" OR "offshore wind" OR "wind powe...

# %%
data = pd.read_csv('../data/raw/965cc6b1-31dd-4ec0-a132-088f6cf0befb.csv')
data.head()
# Out:
#    source object created_at_date updated_at_date version_id is_deleted  \
# 0  indeed    job      2022-02-19      2022-02-19   514a6fcd        NaN
# 1  indeed    job      2022-10-19      2022-10-21   514a6fcd        NaN
# 2  indeed    job      2022-01-18      2022-01-19   514a6fcd        NaN
# 3  indeed    job      2023-06-14      2023-06-16   6c92f412        NaN
# 4  indeed    job      2023-04-24      2023-04-25   6c92f412        NaN
#
#                         doc_id  \
# 0             9fce55aba057f5be
# 1             307f72ab0eba486e
# 2             efe063ba25d8a952
# 3  indeed_job_9b22368ee3dbb98d
# 4  indeed_job_f979a30078d2d557
#
#                                            doc_title     doc_source_id  \
# 0                             Regional Sales Manager               NaN
# 1                                        Manager EHS               NaN
# 2  Offshore Substation Engineering Manager - Kiew...               NaN
# ...
